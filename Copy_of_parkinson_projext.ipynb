# %% [markdown]
# <a href="https://colab.research.google.com/github/mudnighrs/Parkinsons_Disease_Prediction/blob/main/Copy_of_parkinson_projext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("parkinsonsDisease.csv")
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819             NaN
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
df["status"].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
df["status"].value_counts().plot.bar(figsize=(4,4))
# Out:
# <Axes: xlabel='status'>

# %%
df.isna().count()
# Out:
# MDVP:Fo(Hz)         195
# MDVP:Fhi(Hz)        195
# MDVP:Flo(Hz)        195
# MDVP:Jitter(%)      195
# MDVP:Jitter(Abs)    195
# MDVP:RAP            195
# MDVP:PPQ            195
# Jitter:DDP          195
# MDVP:Shimmer        195
# MDVP:Shimmer(dB)    195
# Shimmer:APQ3        195
# Shimmer:APQ5        195
# MDVP:APQ            195
# Shimmer:DDA         195
# NHR                 195
# HNR                 195
# status              195
# RPDE                195
# DFA                 195
# spread1             195
# spread2             195
# D2                  195
# PPE                 195
# Gender              195
# dtype: int64

# %%
df.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# Gender               object
# dtype: object

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   194.000000    189.000000    194.000000      192.000000
# mean    154.402232    197.377048    116.327515        0.006201
# std      41.425925     92.440702     43.633999        0.004867
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.423000    135.069000     84.181500        0.003460
# 50%     149.239500    175.829000    104.205000        0.004940
# 75%     183.144500    221.300000    140.532750        0.007285
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       194 non-null    float64
#  1   MDVP:Fhi(Hz)      189 non-null    float64
#  2   MDVP:Flo(Hz)      194 non-null    float64
#  3   MDVP:Jitter(%)    192 non-null    float64
#  4   MDVP:Jitter(Abs)  195 non-null    float64
#  5   MDVP:RAP          195 non-null    float64
#  6   MDVP:PPQ          195 non-null    float64
#  7   Jitter:DDP        195 non-null    float64
#  8   MDVP:Shimmer      195 non-null    float64
#  9   MDVP:Shimmer(dB)  195 non-null    float64
#  10  Shimmer:APQ3      195 non-null    float64
#  11  Shimmer:APQ5      194 non-null    float64
#  12  MDVP:APQ          187 non-null    float64
#  13  Shimmer:DDA       195 non-null    float64
#  14  NHR               195 non-null    float64
#  15  HNR               195 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# MDVP:Fo(Hz)         1
# MDVP:Fhi(Hz)        6
# MDVP:Flo(Hz)        1
# MDVP:Jitter(%)      3
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        1
# MDVP:APQ            8
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             2
# spread2             0
# D2                  0
# PPE                 0
# Gender              0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer


#fill missing  values with mean

num_imputer=SimpleImputer(strategy="mean")

#define columns

num_features=["MDVP:Fo(Hz)","MDVP:Fhi(Hz)", "MDVP:Flo(Hz)","MDVP:Jitter(%)","MDVP:Jitter(Abs)","MDVP:RAP","MDVP:PPQ","Jitter:DDP","MDVP:Shimmer","MDVP:Shimmer(dB)","Shimmer:APQ3","Shimmer:APQ5","MDVP:APQ","Shimmer:DDA","NHR","HNR","status","RPDE","DFA","spread1","spread2","D2","PPE"]

#Create an imputer(something that fills missing data)
imputer=ColumnTransformer([("num_imputer",num_imputer,num_features)],remainder="passthrough")
filled_ar= imputer.fit_transform(df)
filled_ar
# Out:
# array([[119.992, 157.302, 74.997, ..., 2.301442, 0.284654, 'Male'],
#        [122.4, 148.65, 113.819, ..., 2.486855, 0.368674, 'Male'],
#        [116.682, 131.111, 111.555, ..., 2.342259, 0.332634, 'Female'],
#        ...,
#        [174.688, 240.005, 74.287, ..., 2.679772, 0.131728, 'Female'],
#        [198.764, 396.961, 74.904, ..., 2.138608, 0.123306, 'Female'],
#        [214.289, 260.277, 77.973, ..., 2.555477, 0.148569, 'Male']],
#       dtype=object)

# %%
filled_df=pd.DataFrame(filled_ar,columns=["MDVP:Fo(Hz)","MDVP:Fhi(Hz)", "MDVP:Flo(Hz)","MDVP:Jitter(%)","MDVP:Jitter(Abs)","MDVP:RAP","MDVP:PPQ","Jitter:DDP","MDVP:Shimmer","MDVP:Shimmer(dB)","Shimmer:APQ3","Shimmer:APQ5","MDVP:APQ","Shimmer:DDA","NHR","HNR","status","RPDE","DFA","spread1","spread2","D2","PPE","Gender"])
filled_df
# Out:
#     MDVP:Fo(Hz) MDVP:Fhi(Hz) MDVP:Flo(Hz) MDVP:Jitter(%) MDVP:Jitter(Abs)  \
# 0       119.992      157.302       74.997        0.00784          0.00007
# 1         122.4       148.65      113.819       0.006201          0.00008
# 2       116.682      131.111      111.555         0.0105          0.00009
# 3       116.676      137.871      111.366        0.00997          0.00009
# 4       116.014      141.781      110.655        0.01284          0.00011
# ..          ...          ...          ...            ...              ...
# 190     174.188      230.978       94.261        0.00459          0.00003
# 191     209.516      253.017       89.488        0.00564          0.00003
# 192     174.688      240.005       74.287         0.0136          0.00008
# 193     198.764      396.961       74.904         0.0074          0.00004
# 194     214.289      260.277       77.973        0.00567          0.00003
#
#     MDVP:RAP MDVP:PPQ Jitter:DDP MDVP:Shimmer MDVP:Shimmer(dB)  ...      NHR  \
# ...

# %%
filled_df.isna().sum()
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# Gender              0
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
categorical_features=["Gender"]
one_hot=OneHotEncoder()
transformer=ColumnTransformer([("one_hot",one_hot,categorical_features)],remainder="passthrough")
transformed_ar =transformer.fit_transform(filled_df)
transformed_ar
# Out:
# array([[0.0, 0.0, 1.0, ..., 0.266482, 2.301442, 0.284654],
#        [0.0, 0.0, 1.0, ..., 0.33559, 2.486855, 0.368674],
#        [0.0, 1.0, 0.0, ..., 0.311173, 2.342259, 0.332634],
#        ...,
#        [0.0, 1.0, 0.0, ..., 0.158453, 2.679772, 0.131728],
#        [0.0, 1.0, 0.0, ..., 0.207454, 2.138608, 0.123306],
#        [0.0, 0.0, 1.0, ..., 0.190667, 2.555477, 0.148569]], dtype=object)

# %%
transformed_df=pd.DataFrame(transformed_ar,columns=["NULL","Male","Female","MDVP:Fo(Hz)","MDVP:Fhi(Hz)","MDVP:Flo(Hz)","MDVP:Jitter(%)","MDVP:Jitter(Abs)","MDVP:RAP","MDVP:PPQ","Jitter:DDP","MDVP:Shimmer","MDVP:Shimmer(dB)","Shimmer:APQ3","Shimmer:APQ5","MDVP:APQ","Shimmer:DDA","NHR","HNR","status","RPDE","DFA","spread1","spread2","D2","PPE"])
transformed_df
# Out:
#     NULL Male Female MDVP:Fo(Hz) MDVP:Fhi(Hz) MDVP:Flo(Hz) MDVP:Jitter(%)  \
# 0    0.0  0.0    1.0     119.992      157.302       74.997        0.00784
# 1    0.0  0.0    1.0       122.4       148.65      113.819       0.006201
# 2    0.0  1.0    0.0     116.682      131.111      111.555         0.0105
# 3    0.0  1.0    0.0     116.676      137.871      111.366        0.00997
# 4    0.0  0.0    1.0     116.014      141.781      110.655        0.01284
# ..   ...  ...    ...         ...          ...          ...            ...
# 190  0.0  1.0    0.0     174.188      230.978       94.261        0.00459
# 191  0.0  0.0    1.0     209.516      253.017       89.488        0.00564
# 192  0.0  1.0    0.0     174.688      240.005       74.287         0.0136
# 193  0.0  1.0    0.0     198.764      396.961       74.904         0.0074
# 194  0.0  0.0    1.0     214.289      260.277       77.973        0.00567
#
#     MDVP:Jitter(Abs) MDVP:RAP MDVP:PPQ  ... Shimmer:DDA      NHR     HNR  \
# ...

# %%
parkinson_df=transformed_df.drop("NULL",axis=1)
parkinson_df
# Out:
#     Male Female MDVP:Fo(Hz) MDVP:Fhi(Hz) MDVP:Flo(Hz) MDVP:Jitter(%)  \
# 0    0.0    1.0     119.992      157.302       74.997        0.00784
# 1    0.0    1.0       122.4       148.65      113.819       0.006201
# 2    1.0    0.0     116.682      131.111      111.555         0.0105
# 3    1.0    0.0     116.676      137.871      111.366        0.00997
# 4    0.0    1.0     116.014      141.781      110.655        0.01284
# ..   ...    ...         ...          ...          ...            ...
# 190  1.0    0.0     174.188      230.978       94.261        0.00459
# 191  0.0    1.0     209.516      253.017       89.488        0.00564
# 192  1.0    0.0     174.688      240.005       74.287         0.0136
# 193  1.0    0.0     198.764      396.961       74.904         0.0074
# 194  0.0    1.0     214.289      260.277       77.973        0.00567
#
#     MDVP:Jitter(Abs) MDVP:RAP MDVP:PPQ Jitter:DDP  ... Shimmer:DDA      NHR  \
# ...

# %%
parkinson_df
# Out:
#     Male Female MDVP:Fo(Hz) MDVP:Fhi(Hz) MDVP:Flo(Hz) MDVP:Jitter(%)  \
# 0    0.0    1.0     119.992      157.302       74.997        0.00784
# 1    0.0    1.0       122.4       148.65      113.819       0.006201
# 2    1.0    0.0     116.682      131.111      111.555         0.0105
# 3    1.0    0.0     116.676      137.871      111.366        0.00997
# 4    0.0    1.0     116.014      141.781      110.655        0.01284
# ..   ...    ...         ...          ...          ...            ...
# 190  1.0    0.0     174.188      230.978       94.261        0.00459
# 191  0.0    1.0     209.516      253.017       89.488        0.00564
# 192  1.0    0.0     174.688      240.005       74.287         0.0136
# 193  1.0    0.0     198.764      396.961       74.904         0.0074
# 194  0.0    1.0     214.289      260.277       77.973        0.00567
#
#     MDVP:Jitter(Abs) MDVP:RAP MDVP:PPQ Jitter:DDP  ... Shimmer:DDA      NHR  \
# ...

# %%
affected = parkinson_df[parkinson_df["status"]==1]
unaffected =  parkinson_df[parkinson_df["status"]==0]
affected.shape,unaffected.shape
# Out:
# ((147, 25), (48, 25))

# %%
x = parkinson_df.drop("status",axis=1)
y = parkinson_df["status"]
y=y.astype("int")

# %%
np.random.seed=42


from imblearn.over_sampling import SMOTE
oversample = SMOTE( sampling_strategy='auto', random_state=None, k_neighbors=5, n_jobs=None)
x_res,y_res = oversample.fit_resample(x,y)

# %%
np.random.seed=42

x_res.shape,y_res.shape
# Out:
# ((294, 24), (294,))

# %%
np.random.seed=42

y_res.value_counts()
# Out:
# status
# 1    147
# 0    147
# Name: count, dtype: int64

# %%
x_res
# Out:
#          Male    Female MDVP:Fo(Hz) MDVP:Fhi(Hz) MDVP:Flo(Hz) MDVP:Jitter(%)  \
# 0         0.0       1.0     119.992      157.302       74.997        0.00784
# 1         0.0       1.0       122.4       148.65      113.819       0.006201
# 2         1.0       0.0     116.682      131.111      111.555         0.0105
# 3         1.0       0.0     116.676      137.871      111.366        0.00997
# 4         0.0       1.0     116.014      141.781      110.655        0.01284
# ..        ...       ...         ...          ...          ...            ...
# 289  0.928231  0.071769  176.631933   241.634298    74.569841       0.013122
# 290       0.0       1.0  122.410984   129.249027   116.442859       0.005148
# 291   0.92989   0.07011   199.51782   386.869116    75.926481       0.007277
# 292  0.731387  0.268613   238.41921   245.085643   230.122815       0.002971
# 293  0.845461  0.154539  257.849497   264.481808   236.459988       0.003229
#
# ...

# %%
from sklearn import preprocessing
scaler=preprocessing.MinMaxScaler()
d=scaler.fit_transform(x_res)
scaled_x_res = pd.DataFrame(d,columns=x_res.columns)
scaled_x_res
# Out:
#          Male    Female  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  \
# 0    0.000000  1.000000     0.184308      0.112592      0.054815
# 1    0.000000  1.000000     0.198327      0.094930      0.278323
# 2    1.000000  0.000000     0.165039      0.059128      0.265288
# 3    1.000000  0.000000     0.165004      0.072927      0.264200
# 4    0.000000  1.000000     0.161150      0.080909      0.260107
# ..        ...       ...          ...           ...           ...
# 289  0.928231  0.071769     0.514047      0.284739      0.052356
# 290  0.000000  1.000000     0.198391      0.055327      0.293429
# 291  0.929890  0.070110     0.647281      0.581206      0.060166
# 292  0.731387  0.268613     0.873752      0.291784      0.947913
# 293  0.845461  0.154539     0.986869      0.331377      0.984398
#
#      MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  ...  \
# 0          0.195680          0.249012  0.145472  0.247588    0.145288  ...
# ...

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=0.04)
sel.fit(scaled_x_res)
sel.get_support()
# Out:
# array([ True,  True,  True, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True, False, False, False, False])

# %%
import seaborn as sns


final_preprocessed=scaled_x_res.assign(target=y_res)
final_preprocessed
# Out:
#          Male    Female  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  \
# 0    0.000000  1.000000     0.184308      0.112592      0.054815
# 1    0.000000  1.000000     0.198327      0.094930      0.278323
# 2    1.000000  0.000000     0.165039      0.059128      0.265288
# 3    1.000000  0.000000     0.165004      0.072927      0.264200
# 4    0.000000  1.000000     0.161150      0.080909      0.260107
# ..        ...       ...          ...           ...           ...
# 289  0.928231  0.071769     0.514047      0.284739      0.052356
# 290  0.000000  1.000000     0.198391      0.055327      0.293429
# 291  0.929890  0.070110     0.647281      0.581206      0.060166
# 292  0.731387  0.268613     0.873752      0.291784      0.947913
# 293  0.845461  0.154539     0.986869      0.331377      0.984398
#
#      MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  ...  \
# 0          0.195680          0.249012  0.145472  0.247588    0.145288  ...
# ...

# %%
import seaborn as sns
sns.heatmap(final_preprocessed.corr())
# Out:
# <Axes: >

# %%
np.random.seed=42
from  sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
np.random.seed=42
x_train,x_test,y_train,y_test = train_test_split(scaled_x_res,y_res,test_size=0.3)

clf=RandomForestClassifier()

clf.fit(x_train,y_train)

clf.score(x_test,y_test)
# Out:
# 0.9325842696629213

# %%
np.random.seed=42
shuffled_final_preprocessed=final_preprocessed.sample(frac=1)

X = shuffled_final_preprocessed.drop("target", axis=1)
Y = shuffled_final_preprocessed["target"]



x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3)

clf=RandomForestClassifier()

clf.fit(x_train,y_train)

clf.score(x_test,y_test)
# Out:
# 0.9438202247191011

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(clf,scaled_x_res,y_res)
# Out:
# array([0.86440678, 0.77966102, 0.93220339, 0.89830508, 0.94827586])

# %%
cross_val_score(clf,scaled_x_res,y_res).mean()
# Out:
# 0.9014611338398598

# %%
np.random.seed=42

from sklearn.tree import DecisionTreeClassifier

clf =DecisionTreeClassifier(criterion = "entropy")

clf.fit(x_train,y_train)

print(clf.score(x_test,y_test))
print(cross_val_score(clf,scaled_x_res,y_res).mean())
# Out:
# 0.9213483146067416
# 0.8811805961426067

# %%
np.random.seed=42

from sklearn.tree import DecisionTreeClassifier

clf =DecisionTreeClassifier(criterion = "gini")

clf.fit(x_train,y_train)

print(clf.score(x_test,y_test))
print(cross_val_score(clf,scaled_x_res,y_res).mean())
# Out:
# 0.9101123595505618
# 0.8710111046171829

# %%
df.isna().sum()
# Out:
# MDVP:Fo(Hz)         1
# MDVP:Fhi(Hz)        6
# MDVP:Flo(Hz)        1
# MDVP:Jitter(%)      3
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        1
# MDVP:APQ            8
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             2
# spread2             0
# D2                  0
# PPE                 0
# Gender              0
# dtype: int64

# %%
filled_df.isna().sum()
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# Gender              0
# dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB
clf =GaussianNB()

clf.fit(x_train,y_train)

print(clf.score(x_test,y_test))
print(cross_val_score(clf,scaled_x_res,y_res).mean())
# Out:
# 0.7865168539325843
# 0.7789012273524254

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean')
classifier.fit(x_train, y_train)
print(classifier.score(x_test,y_test))
print(cross_val_score(classifier,scaled_x_res,y_res).mean())
# Out:
# 0.9213483146067416
# 0.8709526592635886

# %%
from sklearn.model_selection import RandomizedSearchCV

grid =  { "n_estimators":[10,100,200,300,400,500,1000,1200],
         "max_depth":[None,5,10,20,30],
         "max_features":["auto","sqrt"],
         "min_samples_split": [2,4,6],
         "min_samples_leaf":[1,2,4]
         }
np.random.seed=42

x_train,x_test,y_train,y_test = train_test_split(scaled_x_res,y_res,test_size=0.3)


clf = RandomForestClassifier (n_jobs=5)
#njobs specifies the how much part of procesor is to be assigned for the given machine learning model;

#setup RandomisedSearchCV
rs_clf= RandomizedSearchCV(estimator=clf,
                          param_distributions=grid,
                          n_iter =50,# number of models to try
                          cv=5,
                          verbose=2)


#fit the  randomised searchCV version of clf
rs_clf.fit(x_train,y_train)
rs_clf.best_params_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   0.0s
# ...

# %%
rs_clf.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 4,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': None}

# %%
rs_clf.score(x_test,y_test)
# Out:
# 0.9662921348314607

# %%
from sklearn.model_selection import GridSearchCV ,train_test_split

np.random.seed=42


x_train,x_test,y_train,y_test = train_test_split(scaled_x_res,y_res,test_size=0.3)

grid =  { "n_estimators":[10,100,200,300,400,500,1000,1200],
         "max_depth":[None,5,10,20,30],
         "max_features":["auto","sqrt"],
         "min_samples_split": [2,4,6],
         "min_samples_leaf":[1,2,4]
         }

#setup GridSearchCV
gs_clf= GridSearchCV(estimator=clf,
                          param_grid=grid,

                          cv=5,
                          verbose=2)


#fit the  randomised searchCV versio of clf
gs_clf.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 720 candidates, totalling 3600 fits
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# ...

# %%
gs_clf.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
gs_clf.score(x_test,y_test)
# Out:
# 0.8651685393258427

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier

adaClf = AdaBoostClassifier(random_state=42,estimator=RandomForestClassifier(),algorithm="SAMME")
adaClf.fit(x_train, y_train)
print(adaClf.score(x_test, y_test))
print(cross_val_score(adaClf,scaled_x_res,y_res).mean())
# Out:
# 0.9213483146067416
# 0.8980713033313851

# %%
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier

random_seed=42
gd = GradientBoostingClassifier()

# Fit the model

gd.fit(x_train, y_train)
print(gd.score(x_test, y_test))
print(cross_val_score(gd,scaled_x_res,y_res).mean())
# Out:
# 0.9438202247191011
# 0.9320864991233198

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier

random_seed=42
xg = XGBClassifier()

# Fit the model

xg.fit(x_train, y_train)
print(xg.score(x_test, y_test))
# Out:
# 0.9438202247191011

# %%
#RANDOM FOREST
from sklearn.metrics import classification_report
y_preds=clf.predict(x_test)
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        47
#            1       1.00      0.88      0.94        42
#
#     accuracy                           0.94        89
#    macro avg       0.95      0.94      0.94        89
# weighted avg       0.95      0.94      0.94        89

# %%
np.random.seed=42
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

def evaluate_model(x_test,y_test,model):
    y_preds=clf.predict(x_test)
    print(classification_report(y_test,y_preds))
    y_probs = clf.predict_proba(x_test)
    y_probs_positive=y_probs[:,1]
    fpr,tpr,thresholds = roc_curve(y_test,y_probs_positive)
    #plot roc curve
    plt.plot(fpr,tpr,color="darkblue", label ="ROC")

    #plot line with no predictive power(baseline)
    plt.plot([0,1],[0,1],color="lightblue",linestyle="--",label="guessing")
    #Customise the plot
    plt.xlabel ("FPR")
    plt.ylabel("TPR")
    plt.title("ROC")
    plt.legend()
    plt.show()

    print("AREA UNDER ROC CURVE =",roc_auc_score(y_test,y_probs_positive))
    sns.set(font_scale=1.5)

    #create confussion matrix
    conf_mat = confusion_matrix(y_test,y_preds)

    fig,ax=plt.subplots(figsize=(3,3))
    ax = sns.heatmap(conf_mat,annot=True,cbar=False,cmap="Blues")
    plt.xlabel("ACTUAL")
    plt.ylabel("PREDICTED")

evaluate_model(x_test,y_test,classifier)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        43
#            1       0.98      0.91      0.94        46
#
#     accuracy                           0.94        89
#    macro avg       0.94      0.94      0.94        89
# weighted avg       0.95      0.94      0.94        89
# AREA UNDER ROC CURVE = 0.993427704752275

# %%
len(x_test)

# %%
#USING OPTIMISED PARAMETER AS GIVEN BY GRID SEARCH CV

np.random.seed=42
shuffled_final_preprocessed=final_preprocessed.sample(frac=1)

X = shuffled_final_preprocessed.drop("target", axis=1)
Y = shuffled_final_preprocessed["target"]



x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3)

clf=RandomForestClassifier(max_depth=20,
                           max_features="sqrt",
                           min_samples_leaf=2,
                           min_samples_split=2,
                           n_estimators=200)

clf.fit(x_train,y_train)

clf.score(x_test,y_test)
evaluate_model(x_test,y_test,clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        43
#            1       0.98      0.91      0.94        46
#
#     accuracy                           0.94        89
#    macro avg       0.94      0.94      0.94        89
# weighted avg       0.95      0.94      0.94        89
# AREA UNDER ROC CURVE = 0.993427704752275

# %%
final_preprocessed.to_csv("final_preprocessed_data.csv")
